# %%
# Import our dependencies
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as skl
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
import tensorflow as tf

# ***************************
# ***                     ***
# ***    SET VARIABLES    ***
# ***                     ***
# ***************************


# STOCK SYMBOL TO PROCESS:
input_symbol_01 = "^VIX"
print(f"Symbol 01: {input_symbol_01}")
input_symbol_02 = "^VIX3M"
print(f"Symbol 02: {input_symbol_02}")
input_symbol_03 = "SPY"
print(f"Symbol 03: {input_symbol_03}")

days_in_future_that_result_is_calculated = 252
print(f"Days in future that result is calculated: {days_in_future_that_result_is_calculated}")

reversion_low_value = 12
print(f"reversion_low_value: {reversion_low_value}")

reversion_high_value = 20
print(f"reversion_high_value: {reversion_high_value}")

optimization_max_epochs = 20
print(f"optimization_max_epochs: {optimization_max_epochs}")

# Max 10:
optimization_max_hidden_layers = 10
print(f"optimization_max_hidden_layers: {optimization_max_hidden_layers}")

optimization_max_nodes = 200
print(f"optimization_max_nodes: {optimization_max_nodes}")

# SCALE THE DATA? "Y" or "N":
scale_data = "Y"
print(f"Scale data: {scale_data}")

# Create a StandardScaler instance
# scaler = StandardScaler()
# relu_only = False

# Create a MinMaxScaler instance
scaler = MinMaxScaler()
relu_only = True

input_column_list_for_X = [
    input_symbol_01+"_close"
    , 
    input_symbol_02+"_close"
    # , 
    # "percentage"
    # ,
    # "percentage_boolean"
    # ,
    # "reversion_boolean"
    # , 
    # input_symbol_03+"_close"
    ]
print (f"input_column_list_for_X: {input_column_list_for_X}")

output_col_for_y = [
    # "future_result"
    "future_result_boolean"
    ]
print (f"output_col_for_y: {output_col_for_y}")

if (input_column_list_for_X == ['percentage_boolean', 'reversion_boolean']) & (output_col_for_y == ['future_result_boolean']):
  relu_only = True
# Out:
# Symbol 01: ^VIX
# Symbol 02: ^VIX3M
# Symbol 03: SPY
# Days in future that result is calculated: 252
# reversion_low_value: 12
# reversion_high_value: 20
# optimization_max_epochs: 20
# optimization_max_hidden_layers: 10
# optimization_max_nodes: 200
# Scale data: Y
# input_column_list_for_X: ['^VIX_close', '^VIX3M_close']
# output_col_for_y: ['future_result_boolean']

# %%
pip install yahoo_fin
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yahoo_fin
#   Downloading yahoo_fin-0.8.9.1-py3-none-any.whl (10 kB)
# Collecting requests-html (from yahoo_fin)
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Collecting feedparser (from yahoo_fin)
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from yahoo_fin) (2.27.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from yahoo_fin) (1.5.3)
# Collecting sgmllib3k (from feedparser->yahoo_fin)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (1.22.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (3.4)
# Collecting pyquery (from requests-html->yahoo_fin)
#   Downloading pyquery-2.0.0-py3-none-any.whl (22 kB)
# Collecting fake-useragent (from requests-html->yahoo_fin)
#   Downloading fake_useragent-1.1.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 2.8 MB/s eta 0:00:00
# Collecting parse (from requests-html->yahoo_fin)
#   Downloading parse-1.19.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Collecting bs4 (from requests-html->yahoo_fin)
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting w3lib (from requests-html->yahoo_fin)
#   Downloading w3lib-2.1.1-py3-none-any.whl (21 kB)
# Collecting pyppeteer>=0.0.14 (from requests-html->yahoo_fin)
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Collecting importlib-metadata>=1.4 (from pyppeteer>=0.0.14->requests-html->yahoo_fin)
#   Downloading importlib_metadata-6.6.0-py3-none-any.whl (22 kB)
# Collecting pyee<9.0.0,>=8.1.0 (from pyppeteer>=0.0.14->requests-html->yahoo_fin)
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.65.0)
# Collecting websockets<11.0,>=10.0 (from pyppeteer>=0.0.14->requests-html->yahoo_fin)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->yahoo_fin) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->requests-html->yahoo_fin) (4.11.2)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.10/dist-packages (from pyquery->requests-html->yahoo_fin) (4.9.2)
# Collecting cssselect>=1.2.0 (from pyquery->requests-html->yahoo_fin)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.15.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.4.1)
# Building wheels for collected packages: bs4, parse, sgmllib3k
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1257 sha256=0afd0b85fa87bee11992a0ed9dabc149755ee309d402ce4de09ad38dbf816242
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
#   Building wheel for parse (setup.py) ... done
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24570 sha256=9ae56e17278d8f2454d16b322c4e0cda330628080de47e47dd7db8e66e02896b
#   Stored in directory: /root/.cache/pip/wheels/70/4b/f0/eaf5a8de646d8676dc25caa01949b9f9d883b8fa2efb435bc3
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=2e1c667fbeb76f2b633a10e03ce3218b8603858d5f11fb87312272eaa3065a4a
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built bs4 parse sgmllib3k
# Installing collected packages: sgmllib3k, pyee, parse, fake-useragent, websockets, w3lib, importlib-metadata, feedparser, cssselect, pyquery, pyppeteer, bs4, requests-html, yahoo_fin
# Successfully installed bs4-0.0.1 cssselect-1.2.0 fake-useragent-1.1.3 feedparser-6.0.10 importlib-metadata-6.6.0 parse-1.19.0 pyee-8.2.2 pyppeteer-1.0.2 pyquery-2.0.0 requests-html-0.10.0 sgmllib3k-1.0.0 w3lib-2.1.1 websockets-10.4 yahoo_fin-0.8.9.1

# %%
# pip install requests_html

# %%
from yahoo_fin.stock_info import get_data

# %%
# Load ticker1 historical data from Yahoo Finance API
from datetime import date
today = date.today()
curr_date = today.strftime("%m/%d/%Y")
df_01 = get_data(input_symbol_01, start_date="01/01/2000", end_date=curr_date, index_as_date = False, interval="1d")
df_01_min_date = (df_01.iloc[0]["date"])
df_01
# Out:
#            date       open       high        low      close   adjclose  \
# 0    2000-01-03  24.360001  26.150000  23.980000  24.209999  24.209999
# 1    2000-01-04  24.940001  27.180000  24.799999  27.010000  27.010000
# 2    2000-01-05  27.980000  29.000000  25.850000  26.410000  26.410000
# 3    2000-01-06  26.680000  26.709999  24.700001  25.730000  25.730000
# 4    2000-01-07  25.139999  25.170000  21.719999  21.719999  21.719999
# ...         ...        ...        ...        ...        ...        ...
# 6110 2023-06-05  15.280000  15.290000  14.660000  14.730000  14.730000
# 6111 2023-06-06  14.910000  14.970000  13.950000  13.960000  13.960000
# 6112 2023-06-07  14.140000  14.290000  13.770000  13.940000  13.940000
# 6113 2023-06-08  14.140000  14.210000  13.530000  13.650000  13.650000
# 6114 2023-06-09  13.780000  14.140000  13.500000  13.830000  13.830000
#
#       volume ticker
# 0        0.0   ^VIX
# 1        0.0   ^VIX
# 2        0.0   ^VIX
# 3        0.0   ^VIX
# 4        0.0   ^VIX
# ...      ...    ...
# 6110     0.0   ^VIX
# 6111     0.0   ^VIX
# 6112     0.0   ^VIX
# 6113     0.0   ^VIX
# 6114     0.0   ^VIX
#
# [6115 rows x 8 columns]

# %%
# Load ticker2 historical data from Yahoo Finance API
from datetime import date
today = date.today()
curr_date = today.strftime("%m/%d/%Y")
df_02 = get_data(input_symbol_02, start_date="01/01/2000", end_date=curr_date, index_as_date = False, interval="1d")
df_02_min_date = (df_02.iloc[0]["date"])
df_02
# Out:
#            date       open       high        low      close   adjclose  \
# 0    2006-07-17  18.049999  18.049999  18.049999  18.049999  18.049999
# 1    2006-07-18  17.219999  17.219999  17.219999  17.219999  17.219999
# 2    2006-07-19  15.600000  15.600000  15.600000  15.600000  15.600000
# 3    2006-07-20  16.309999  16.309999  16.309999  16.309999  16.309999
# 4    2006-07-21  17.040001  17.040001  17.040001  17.040001  17.040001
# ...         ...        ...        ...        ...        ...        ...
# 4250 2023-06-05  18.230000  18.330000  17.900000  17.900000  17.900000
# 4251 2023-06-06  18.059999  18.090000  16.879999  17.040001  17.040001
# 4252 2023-06-07  17.190001  17.440001  16.870001  17.139999  17.139999
# 4253 2023-06-08  17.270000  17.410000  16.740000  16.860001  16.860001
# 4254 2023-06-09  16.860001  17.250000  16.700001  16.959999  16.959999
#
#       volume  ticker
# 0          0  ^VIX3M
# 1          0  ^VIX3M
# 2          0  ^VIX3M
# 3          0  ^VIX3M
# 4          0  ^VIX3M
# ...      ...     ...
# 4250       0  ^VIX3M
# 4251       0  ^VIX3M
# 4252       0  ^VIX3M
# 4253       0  ^VIX3M
# 4254       0  ^VIX3M
#
# [4255 rows x 8 columns]

# %%
# Load ticker3 historical data from Yahoo Finance API
from datetime import date
today = date.today()
curr_date = today.strftime("%m/%d/%Y")
df_03 = get_data(input_symbol_03, start_date="01/01/2000", end_date=curr_date, index_as_date = False, interval="1d")
df_03_min_date = (df_03.iloc[0]["date"])
df_03
# Out:
#            date        open        high         low       close    adjclose  \
# 0    2000-01-03  148.250000  148.250000  143.875000  145.437500   94.946434
# 1    2000-01-04  143.531250  144.062500  139.640625  139.750000   91.233444
# 2    2000-01-05  139.937500  141.531250  137.250000  140.000000   91.396660
# 3    2000-01-06  139.625000  141.500000  137.750000  137.750000   89.927773
# 4    2000-01-07  140.312500  145.750000  140.062500  145.750000   95.150429
# ...         ...         ...         ...         ...         ...         ...
# 5892 2023-06-05  428.279999  429.619995  426.369995  427.100006  427.100006
# 5893 2023-06-06  426.670013  428.579987  425.989990  428.029999  428.029999
# 5894 2023-06-07  428.440002  429.619995  426.109985  426.549988  426.549988
# 5895 2023-06-08  426.619995  429.600006  425.820007  429.130005  429.130005
# 5896 2023-06-09  429.959991  431.989990  428.869995  429.899994  429.899994
#
#         volume ticker
# 0      8164300    SPY
# 1      8089800    SPY
# 2     12177900    SPY
# 3      6227200    SPY
# 4      8066500    SPY
# ...        ...    ...
# 5892  65460200    SPY
# 5893  64022200    SPY
# 5894  85373300    SPY
# 5895  61952800    SPY
# 5896  85742800    SPY
#
# [5897 rows x 8 columns]

# %%
# Find the first date in each dataframe and get the latest date, that way all dataframes start on the same date when concatinated
latest_date = df_01_min_date
if df_02_min_date > latest_date:
  latest_date = df_02_min_date
if df_03_min_date > latest_date:
  latest_date = df_03_min_date
print(latest_date)
# Out:
# 2006-07-17 00:00:00

# %%
df_01 = df_01[df_01.date >= latest_date]
df_01.head(1)
# Out:
#            date   open   high    low      close   adjclose  volume ticker
# 1705 2006-07-17  18.73  18.76  17.75  18.639999  18.639999     0.0   ^VIX

# %%
df_02 = df_02[df_02.date >= latest_date]
df_02.head(1)
# Out:
#         date       open       high        low      close   adjclose  volume  \
# 0 2006-07-17  18.049999  18.049999  18.049999  18.049999  18.049999       0
#
#    ticker
# 0  ^VIX3M

# %%
df_03 = df_03[df_03.date >= latest_date]
df_03.head(1)
# Out:
#            date        open        high         low       close  adjclose  \
# 1642 2006-07-17  123.519997  124.099998  123.150002  123.339996   88.9804
#
#         volume ticker
# 1642  81159000    SPY

# %%
# set the column names based on the ticker symbols
col01 = (f"{input_symbol_01}_close")
col02 = (f"{input_symbol_02}_close")
col03 = (f"{input_symbol_03}_close")
# clean and merge the 3 dataframes, and add some new cols
df = df_01[['date', 'close']].copy()
df = df.rename(columns={'close': col01})
df = df.merge(df_02, on='date')
df = df.rename(columns={'close': col02})
df = df.drop(columns=['open', 'high', 'low', 'adjclose', 'volume', 'ticker'])
df['percentage'] = ""
df['percentage_boolean'] = ""
df['reversion_boolean'] = ""
df = df.merge(df_03, on='date')
df = df.rename(columns={'close': col03})
df = df.drop(columns=['open', 'high', 'low', 'adjclose', 'volume', 'ticker'])
df['future_result'] = ""
df['future_result_boolean'] = ""
df
# Out:
#            date  ^VIX_close  ^VIX3M_close percentage percentage_boolean  \
# 0    2006-07-17   18.639999     18.049999
# 1    2006-07-18   17.740000     17.219999
# 2    2006-07-19   15.550000     15.600000
# 3    2006-07-20   16.209999     16.309999
# 4    2006-07-21   17.400000     17.040001
# ...         ...         ...           ...        ...                ...
# 4250 2023-06-05   14.730000     17.900000
# 4251 2023-06-06   13.960000     17.040001
# 4252 2023-06-07   13.940000     17.139999
# 4253 2023-06-08   13.650000     16.860001
# 4254 2023-06-09   13.830000     16.959999
#
#      reversion_boolean   SPY_close future_result future_result_boolean
# 0                       123.339996
# 1                       123.970001
# 2                       125.690002
# 3                       124.830002
# 4                       123.949997
# ...                ...         ...           ...                   ...
# 4250                    427.100006
# 4251                    428.029999
# 4252                    426.549988
# 4253                    429.130005
# 4254                    429.899994
#
# [4255 rows x 9 columns]

# %%
# loop through the df to populate the new columns
for i in range(len(df)):

    if (i < (len(df))):
      df.percentage[i] = (df[col02][i]/df[col01][i])
      if ( (df[col01][i] > reversion_low_value) & (df[col01][i] < reversion_high_value) ):
        df.reversion_boolean[i] = 1
      else:
        df.reversion_boolean[i] = 0
    if (i < (len(df)-days_in_future_that_result_is_calculated)):
      df.future_result[i] = ((df[col03][i+days_in_future_that_result_is_calculated]-df[col03][i])/df[col03][i])

df = df[df['future_result'] != ""]
# Out:
# <ipython-input-13-3f61b1bae5a6>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.percentage[i] = (df[col02][i]/df[col01][i])
# <ipython-input-13-3f61b1bae5a6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.reversion_boolean[i] = 1
# <ipython-input-13-3f61b1bae5a6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.future_result[i] = ((df[col03][i+days_in_future_that_result_is_calculated]-df[col03][i])/df[col03][i])
# <ipython-input-13-3f61b1bae5a6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.reversion_boolean[i] = 0

# %%
df["percentage"] = pd.to_numeric(df["percentage"])
df["reversion_boolean"] = pd.to_numeric(df["reversion_boolean"])
df["future_result"] = pd.to_numeric(df["future_result"])

for i in range(len(df)):
    if (df['percentage'][i] > 1):
      df.percentage_boolean[i] = 1
    else:
      df.percentage_boolean[i] = 0
    if (df['future_result'][i] > 0):
      df.future_result_boolean[i] = 1
    else:
      df.future_result_boolean[i] = 0

df["future_result_boolean"] = pd.to_numeric(df["future_result_boolean"])
df["percentage_boolean"] = pd.to_numeric(df["percentage_boolean"])
df.dtypes
# Out:
# <ipython-input-14-adbf859450c8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["percentage"] = pd.to_numeric(df["percentage"])
# <ipython-input-14-adbf859450c8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["reversion_boolean"] = pd.to_numeric(df["reversion_boolean"])
# <ipython-input-14-adbf859450c8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["future_result"] = pd.to_numeric(df["future_result"])
# <ipython-input-14-adbf859450c8>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.percentage_boolean[i] = 0
# <ipython-input-14-adbf859450c8>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.future_result_boolean[i] = 1
# <ipython-input-14-adbf859450c8>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.percentage_boolean[i] = 1
# <ipython-input-14-adbf859450c8>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.future_result_boolean[i] = 0
# <ipython-input-14-adbf859450c8>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["future_result_boolean"] = pd.to_numeric(df["future_result_boolean"])
# <ipython-input-14-adbf859450c8>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["percentage_boolean"] = pd.to_numeric(df["percentage_boolean"])
# date                     datetime64[ns]
# ^VIX_close                      float64
# ^VIX3M_close                    float64
# percentage                      float64
# percentage_boolean                int64
# reversion_boolean                 int64
# SPY_close                       float64
# future_result                   float64
# future_result_boolean             int64
# dtype: object

# %%
df
# Out:
#            date  ^VIX_close  ^VIX3M_close  percentage  percentage_boolean  \
# 0    2006-07-17   18.639999     18.049999    0.968348                   0
# 1    2006-07-18   17.740000     17.219999    0.970688                   0
# 2    2006-07-19   15.550000     15.600000    1.003215                   1
# 3    2006-07-20   16.209999     16.309999    1.006169                   1
# 4    2006-07-21   17.400000     17.040001    0.979310                   0
# ...         ...         ...           ...         ...                 ...
# 3998 2022-06-02   24.719999     27.059999    1.094660                   1
# 3999 2022-06-03   24.790001     27.330000    1.102461                   1
# 4000 2022-06-06   25.070000     27.219999    1.085760                   1
# 4001 2022-06-07   24.020000     26.520000    1.104080                   1
# 4002 2022-06-08   23.959999     26.540001    1.107680                   1
#
#       reversion_boolean   SPY_close  future_result  future_result_boolean
# 0                     1  123.339996       0.252392                      1
# 1                     1  123.970001       0.250867                      1
# 2                     1  125.690002       0.221259                      1
# 3                     1  124.830002       0.233437                      1
# 4                     1  123.949997       0.220654                      1
# ...                 ...         ...            ...                    ...
# 3998                  0  417.390015       0.023264                      1
# 3999                  0  410.540009       0.042602                      1
# 4000                  0  411.790009       0.035843                      1
# 4001                  0  415.739990       0.032208                      1
# 4002                  0  411.220001       0.045426                      1
#
# [4003 rows x 9 columns]

# %%
x_axis = '^VIX_close'
y_axis = 'future_result'
c_axis = '^VIX3M_close'
import seaborn as sns
# Draw a seaborn scatter plot
sns.lmplot(x=x_axis,y=y_axis,data=df,fit_reg=True)

# %%
# Draw scatter plot with both input securities
df.plot.scatter(x = x_axis, y = y_axis, c=c_axis, colormap='viridis', s = 10)
# Out:
# <Axes: xlabel='^VIX_close', ylabel='future_result'>

# %%
# Remove target 'y' from features data
y = df[output_col_for_y].values

# %%
# Pick columns to use for input 'X'
X = df[input_column_list_for_X].values

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# %%
# Scale the data if the indicator is set to 'Y'
if scale_data == "N":
  import numpy as np
  X_train = np.asarray(X_train).astype(np.float64)
  X_train_scaled = X_train
  X_test = np.asarray(X_test).astype(np.float64)
  X_test_scaled = X_test
else:
  X_train_scaled = X_scaler.transform(X_train)
  X_test_scaled = X_scaler.transform(X_test)

print(f"Scale Data = {scale_data}")
# Out:
# Scale Data = Y

# %% [markdown]
# ### Created an auto optimization function to determine:
# * Activation
# * Hidden layers
# * Nodes
# * Epochs

# %%
pip install keras-tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.5-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.27.1)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.4)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.3.5 kt-legacy-1.0.5

# %%
number_input_features = len(X_train[0])

# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    if relu_only:
      print("Running relu only")
      activation = hp.Choice('activation',['relu'])
    else:
      activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=number_input_features,
        max_value=number_input_features,
        step=1), activation=activation, 
        input_dim=number_input_features))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    # 10 potential hidden layers max
    for i in range(hp.Int('num_layers', 1, optimization_max_hidden_layers)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            # potential nodes
            min_value=5,
            max_value=optimization_max_nodes,
            step=5),
            activation=activation))
    
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_model

# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    # max epochs
    max_epochs=optimization_max_epochs,
    hyperband_iterations=2)
# Out:
# Running relu only

# %%
print(X_train_scaled.dtype)
print(X_test_scaled.dtype)
print(y_train.dtype)
print(y_test.dtype)
# Out:
# float64
# float64
# int64
# int64

# %%
# Run the kerastuner search for best hyperparameters

tuner.search(X_train_scaled,y_train,validation_data=(X_test_scaled,y_test))
# Out:
# Trial 60 Complete [00h 00m 07s]
# val_accuracy: 0.7682317495346069
#
# Best val_accuracy So Far: 0.7812187671661377
# Total elapsed time: 00h 05m 49s

# %%
# Get best model hyperparameters from the tests that were just completed
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'relu',
#  'first_units': 2,
#  'num_layers': 8,
#  'units_0': 40,
#  'units_1': 35,
#  'units_2': 90,
#  'units_3': 70,
#  'units_4': 35,
#  'units_5': 95,
#  'units_6': 200,
#  'units_7': 125,
#  'units_8': 150,
#  'units_9': 120,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 7,
#  'tuner/bracket': 1,
#  'tuner/round': 1,
#  'tuner/trial_id': '0051'}

# %%
# Evaluate best model against full test data
best_model = tuner.get_best_models(1)[0]

model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)

print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
print(f"Scale Data = {scale_data}")
# Out:
# Running relu only
# 32/32 - 0s - loss: 0.4787 - accuracy: 0.7812 - 433ms/epoch - 14ms/step
# Loss: 0.47870686650276184, Accuracy: 0.7812187671661377
# Scale Data = Y

# %%
# Set variables based on the best result from the auto optimization

activation_type = best_hyper.values['activation']
num_layers = best_hyper.values['num_layers']
num_epochs = best_hyper.values['tuner/epochs']

# %% [markdown]
# ### Compile, Train and Evaluate the Model

# %%
number_input_features = len(X_train[0])

nn = tf.keras.models.Sequential()

# %%
# First hidden layer
hidden_nodes_layer1 = best_hyper.values['units_0']
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation=activation_type)
)
print(f"Layer: 1")
print(f"Nodes: {hidden_nodes_layer1}")

if num_layers >= 2:
  # second hidden layer
  hidden_nodes_layer2 = best_hyper.values['units_1']
  nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation=activation_type))
  print(f"Layer: 2")
  print(f"Nodes: {hidden_nodes_layer2}")

if num_layers >= 3:
  # hidden layer
  hidden_nodes_layer3 = best_hyper.values['units_2']
  nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation=activation_type))
  print(f"Layer: 3")
  print(f"Nodes: {hidden_nodes_layer3}")

if num_layers >= 4:
  # hidden layer
  hidden_nodes_layer4 = best_hyper.values['units_3']
  nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation=activation_type))
  print(f"Layer: 4")
  print(f"Nodes: {hidden_nodes_layer4}")

if num_layers >= 5:
  # hidden layer
  hidden_nodes_layer5 = best_hyper.values['units_4']
  nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer5, activation=activation_type))
  print(f"Layer: 5")
  print(f"Nodes: {hidden_nodes_layer5}")

if num_layers >= 6:
  # hidden layer
  hidden_nodes_layer6 = best_hyper.values['units_5']
  nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer6, activation=activation_type))
  print(f"Layer: 6")
  print(f"Nodes: {hidden_nodes_layer6}")

if num_layers >= 7:
  # hidden layer
  hidden_nodes_layer7 = best_hyper.values['units_6']
  nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer7, activation=activation_type))
  print(f"Layer: 7")
  print(f"Nodes: {hidden_nodes_layer7}")

if num_layers >= 8:
  # hidden layer
  hidden_nodes_layer8 = best_hyper.values['units_7']
  nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer8, activation=activation_type))
  print(f"Layer: 8")
  print(f"Nodes: {hidden_nodes_layer8}")

if num_layers >= 9:
  # hidden layer
  hidden_nodes_layer9 = best_hyper.values['units_8']
  nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer9, activation=activation_type))
  print(f"Layer: 9")
  print(f"Nodes: {hidden_nodes_layer9}")

if num_layers >= 10:
  # hidden layer
  hidden_nodes_layer10 = best_hyper.values['units_9']
  nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer10, activation=activation_type))
  print(f"Layer: 10")
  print(f"Nodes: {hidden_nodes_layer10}")
# Out:
# Layer: 1
# Nodes: 40
# Layer: 2
# Nodes: 35
# Layer: 3
# Nodes: 90
# Layer: 4
# Nodes: 70
# Layer: 5
# Nodes: 35
# Layer: 6
# Nodes: 95
# Layer: 7
# Nodes: 200
# Layer: 8
# Nodes: 125

# %%
# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 40)                120
#
#  dense_11 (Dense)            (None, 35)                1435
#
#  dense_12 (Dense)            (None, 90)                3240
#
#  dense_13 (Dense)            (None, 70)                6370
#
#  dense_14 (Dense)            (None, 35)                2485
#
#  dense_15 (Dense)            (None, 95)                3420
#
#  dense_16 (Dense)            (None, 200)               19200
#
#  dense_17 (Dense)            (None, 125)               25125
#
#  dense_18 (Dense)            (None, 1)                 126
#
# =================================================================
# Total params: 61,521
# Trainable params: 61,521
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(f"Scale Data = {scale_data}")
# Out:
# Scale Data = Y

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=num_epochs)
# Out:
# Epoch 1/20
# 94/94 [==============================] - 3s 6ms/step - loss: 0.5740 - accuracy: 0.7522
# Epoch 2/20
# 94/94 [==============================] - 0s 5ms/step - loss: 0.5591 - accuracy: 0.7522
# Epoch 3/20
# 94/94 [==============================] - 1s 5ms/step - loss: 0.5498 - accuracy: 0.7522
# Epoch 4/20
# 94/94 [==============================] - 0s 5ms/step - loss: 0.5350 - accuracy: 0.7522
# Epoch 5/20
# 94/94 [==============================] - 0s 4ms/step - loss: 0.5202 - accuracy: 0.7522
# Epoch 6/20
# 94/94 [==============================] - 0s 5ms/step - loss: 0.5143 - accuracy: 0.7522
# Epoch 7/20
# 94/94 [==============================] - 0s 5ms/step - loss: 0.5132 - accuracy: 0.7522
# Epoch 8/20
# 94/94 [==============================] - 0s 5ms/step - loss: 0.5042 - accuracy: 0.7538
# Epoch 9/20
# 94/94 [==============================] - 1s 5ms/step - loss: 0.5061 - accuracy: 0.7558
# Epoch 10/20
# 94/94 [==============================] - 0s 5ms/step - loss: 0.5025 - accuracy: 0.7548
# Epoch 11/20
# 94/94 [==============================] - 0s 5ms/step - loss: 0.5015 - accuracy: 0.7588
# Epoch 12/20
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4981 - accuracy: 0.7585
# Epoch 13/20
# 94/94 [==============================] - 0s 5ms/step - loss: 0.5002 - accuracy: 0.7538
# Epoch 14/20
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4956 - accuracy: 0.7618
# Epoch 15/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4973 - accuracy: 0.7622
# Epoch 16/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4946 - accuracy: 0.7698
# Epoch 17/20
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4861 - accuracy: 0.7761
# Epoch 18/20
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4945 - accuracy: 0.7648
# Epoch 19/20
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4947 - accuracy: 0.7615
# Epoch 20/20
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4904 - accuracy: 0.7648

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
print(f"Scale Data = {scale_data}")
print(f"activation_type = {activation_type}")
print(f"num_epochs = {num_epochs}")
print(f"num_layers = {num_layers}")
print(f"Layer 1 Nodes = {hidden_nodes_layer1}")
if num_layers >= 2:
  print(f"Layer 2 Nodes = {hidden_nodes_layer2}")
if num_layers >= 3:
  print(f"Layer 3 Nodes: {hidden_nodes_layer3}")
if num_layers >= 4:
  print(f"Layer 4 Nodes = {hidden_nodes_layer4}")
if num_layers >= 5:
  print(f"Layer 5 Nodes = {hidden_nodes_layer5}")
if num_layers >= 6:
  print(f"Layer 6 Nodes = {hidden_nodes_layer6}")
if num_layers >= 7:
  print(f"Layer 7 Nodes = {hidden_nodes_layer7}")
if num_layers >= 8:
  print(f"Layer 8 Nodes = {hidden_nodes_layer8}")
if num_layers >= 9:
  print(f"Layer 9 Nodes = {hidden_nodes_layer9}")
if num_layers >= 10:
  print(f"Layer 10 Nodes = {hidden_nodes_layer10}")
# Out:
# 32/32 - 1s - loss: 0.4728 - accuracy: 0.7742 - 515ms/epoch - 16ms/step
# Loss: 0.4728052318096161, Accuracy: 0.7742257714271545
# Scale Data = Y
# activation_type = relu
# num_epochs = 20
# num_layers = 8
# Layer 1 Nodes = 40
# Layer 2 Nodes = 35
# Layer 3 Nodes: 90
# Layer 4 Nodes = 70
# Layer 5 Nodes = 35
# Layer 6 Nodes = 95
# Layer 7 Nodes = 200
# Layer 8 Nodes = 125
